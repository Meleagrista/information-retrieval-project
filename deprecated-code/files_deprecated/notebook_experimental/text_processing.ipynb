# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import pprint 
import os

from alive_progress import alive_bar
import time
import sys

from boardgamegeek import BGGClient

# %%
bgg = BGGClient()

# %% [markdown]
# # DATA EXTRACTION

# %%
hot_items = bgg.hot_items('boardgame')
miss = {}
data = []
for item in hot_items:
    try:
        game = bgg.game(game_id=item.id, comments=True)
        with alive_bar(len(game.comments), force_tty=True) as bar:
            for comment in game.comments:
                com_data = {}
                com_data["id"] = item.id
                com_data["title"] = item.name
                com_data["user"] = comment.commenter
                com_data["comment"] = comment.comment
                com_data["rating"] = comment.rating
                data.append(com_data)
                time.sleep(.01)
                bar()
    except:
        print('error')
        miss[item.id] = item.name

# %%
with open("comment_data_demo.json", 'w') as f:
    json.dump(data, f, indent=2) # indent=2 is not needed but makes the file human-readable if the data is nested

# %% [markdown]
# # DATA WRANGLING

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import json
import os
import numpy as np

with open("comment_data_demo.json", 'r') as f:
    post_list = json.load(f)
    
print(f'Amount of comments before any formatting: {len(post_list)}')
    
df = pd.json_normalize(post_list)

# %%
df.head(1)

# %% [markdown]
# ## Reading raw data
# #### File formating
# Not all fields are readable and need to be modified.

# %%
#There are no unredable data
path_original_data=r'C:\Users\Usuario\Documents\JupyterFolder\unimi_files\IR'
df.to_csv(os.path.join(path_original_data,'comment_data_demo.csv'), index=False)

# %% [markdown]
# ## Data cleaning and restructuring procedures

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import json
import os
import numpy as np
path_original_data=r'C:\Users\Usuario\Documents\JupyterFolder\unimi_files\IR'
df=pd.read_csv(os.path.join(path_original_data,'comment_data_demo.csv'), low_memory=False)

# %%
df.head(1)
# Out:
#        id                 title     user comment  rating
# 0  387866  Star Wars: Unlimited  8janek8      pl     NaN

# %% [markdown]
# Perform a quick superficial analysis of the data.

# %%
# Print some statitiscts of the 'comment' field

print(str(round(len(df[df.comment.notnull()])/len(df)*100,2))+'%')
print(df.comment.str.len().max())
print(df.comment.str.len().min())
print(df.comment.str.len().mean())

#Search the number of comments containing searched words within the text of the message
print()

pattern = "random"
print(len(df[df.comment.str.contains(pattern) & df.comment.notnull()]))
print(len(df[df.comment.str.match(pattern) & df.comment.notnull()]))
print(len(df[df.comment.str.fullmatch(pattern) & df.comment.notnull()]))
# Out:
# 99.99%
# 18588.0
# 1.0
# 202.89663664400902
#
# 2806
# 1
# 0

# %%
df = df[df.comment.notnull()]
df = df.reset_index(drop=True)

# %%
# Print the first messages that constains the pattern

print(df.loc[df.comment.str.contains(pattern) & df.comment.notnull(), 'comment'])
# Out:
# 87        After just one play I get the feeling I have s...
# 129       I really don’t get the hype around Heat, but t...
# 165       An okay "deck management” game with a relatabl...
# 295       Update: After some more plays I feel that some...
# 394       [imageID=6940449small inline] This really feel...
#                                 ...
# 129937    More plays with a different game group have si...
# 129963    Interesting legacy role play co-op board game....
# 130050    Played solo. The different scenarios keeps the...
# 130201    Digital version available (PC) Playing solo be...
# 130344    Too hard under the rules in the game and a bit...
# Name: comment, Length: 2806, dtype: object

# %% [markdown]
# #### Transformation
# Modify values to be easier to read.

# %%
# Nothing to transform

# %% [markdown]
# #### Filtering the data
# Limit the results to one country or language.

# %%
from guess_language import guess_language
import enchant
import string
import re

# Function to check if a comment is in English
def is_english_batch(batch):
    # Create a batch of processed texts
    processed_texts = batch['comment'].str.lower().apply(lambda text: re.findall(r"[a-zA-Z0-9']+", text))

    # Create an English dictionary
    english_dictionary = enchant.Dict("en_US")

    # Check if any comment in the batch is in English
    is_english = processed_texts.apply(lambda text: sum(english_dictionary.check(word) for word in text) >= len(text) / 2)

    # Return a boolean Series indicating if each comment is in English
    return is_english

# %%
from tqdm import tqdm
import time
import sys

from alive_progress import alive_bar
from IPython.display import display, HTML

import pandas as pd

# Display the CSS styling
# display(HTML(bar_styling))

# Batch processing
batch_size = 1000  # Number of rows to process in each batch
num_rows = len(df)
result = pd.Series([], dtype='float64')  # Store the results

bar_stat = round(num_rows/batch_size)+1

with tqdm(total=bar_stat, ncols=bar_stat) as pbar:
    for i in range(0, num_rows, batch_size):
        batch = df.iloc[i:i+batch_size]
        batch_english = batch.loc[is_english_batch(batch)]
        result = pd.concat([result, batch_english])
        pbar.update(1)

# Reset the index of the DataFrame
result.reset_index(drop=True, inplace=True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████| 131/131 [06:31<00:00,  2.99s/it]

# %%
# Print the updated DataFrame
result.head(10)
# Out:
#     0        id                     title           user  \
# 0 NaN  387866.0      Star Wars: Unlimited        8janek8
# 1 NaN  387866.0      Star Wars: Unlimited         Irsaan
# 2 NaN  387866.0      Star Wars: Unlimited         ObiKKa
# 3 NaN  387866.0      Star Wars: Unlimited  Stephen Glenn
# 4 NaN  366013.0  Heat: Pedal to the Metal     100pcBlade
# 5 NaN  366013.0  Heat: Pedal to the Metal    360_Piranha
# 6 NaN  366013.0  Heat: Pedal to the Metal    Aardvarkius
# 7 NaN  366013.0  Heat: Pedal to the Metal       abernath
# 8 NaN  366013.0  Heat: Pedal to the Metal       abjohnuf
# 9 NaN  366013.0  Heat: Pedal to the Metal         aby407
#
#                                              comment  rating
# 0                                                 pl     NaN
# 1                Should have been an LCG, not a TCG.     1.0
# 2  Big surprise news in 2023 of this 2024 Star Wa...     NaN
# 3                     Collecting and trading is fun!     NaN
# 4  I was a little disappointed with Heat after my...     7.5
# 5                                        Just, wow.     10.0
# 6   Shrinkwrap  BIN: Not for sale/trade at this time     NaN
# 7  It's fine. I would rather play Automobiles or ...     6.0
# 8                   Boarding School Games back order     NaN
# 9                                              23.08     NaN

# %%
print(len(result))
print(len(df))
print(len(df)-len(result))

df1 = df
df2 = result

import pandas as pd

# Assuming you have two DataFrames: df1 and df2 representing the two databases

# Find rows with differing 'comment' in df1 compared to df2
diff_df1 = df1[~df1['comment'].isin(df2['comment'])]

# Find rows with differing 'comment' in df2 compared to df1
diff_df2 = df2[~df2['comment'].isin(df1['comment'])]

# Concatenate the differing rows into a single DataFrame
diff_combined = pd.concat([diff_df1, diff_df2])

# Reset the index of the resulting DataFrame
diff_combined.reset_index(drop=True, inplace=True)

# Print the differences
diff_combined.head(10)
# Out:
# 119472
# 130346
# 10874
#          id                     title        user  \
# 0  366013.0  Heat: Pedal to the Metal      a2greg
# 1  366013.0  Heat: Pedal to the Metal  alexbatbee
# 2  366013.0  Heat: Pedal to the Metal  ANDREWSOFT
# 3  366013.0  Heat: Pedal to the Metal     angeltg
# 4  366013.0  Heat: Pedal to the Metal      ankara
# 5  366013.0  Heat: Pedal to the Metal     Anxelox
# 6  366013.0  Heat: Pedal to the Metal  Argantonio
# 7  366013.0  Heat: Pedal to the Metal    Arnar146
# 8  366013.0  Heat: Pedal to the Metal     Avantyr
# 9  366013.0  Heat: Pedal to the Metal     badzacz
#
#                                              comment  rating   0
# 0                                                nyp     NaN NaN
# 1                                               zatu     NaN NaN
# 2  Jugadas varias partidas en solitario con el mó...     8.2 NaN
# 3  Partidas rápidas y sencillas con toda la emoci...    10.0 NaN
# 4                                           Juegaken    10.0 NaN
# 5                                          Por xogar     NaN NaN
# 6  Muy buen juego de carreras que exige un par de...     8.0 NaN
# 7                                              Gulli     8.0 NaN
# 8                                                PnP     8.5 NaN
# 9                                                H20     NaN NaN

# %%
result['text_length'] = result['comment'].apply(lambda x: len(x))
result['word_count'] = result['comment'].apply(lambda x: len(x.split()))
result = result[result['word_count'] > 5]
result = result.drop(result.columns[0], axis=1)
result.head(10)
# Out:
#           id                     title          user  \
# 1   387866.0      Star Wars: Unlimited        Irsaan
# 2   387866.0      Star Wars: Unlimited        ObiKKa
# 4   366013.0  Heat: Pedal to the Metal    100pcBlade
# 6   366013.0  Heat: Pedal to the Metal   Aardvarkius
# 7   366013.0  Heat: Pedal to the Metal      abernath
# 10  366013.0  Heat: Pedal to the Metal      adamgrey
# 11  366013.0  Heat: Pedal to the Metal  adamredwoods
# 13  366013.0  Heat: Pedal to the Metal   Addiction2k
# 16  366013.0  Heat: Pedal to the Metal       agilmor
# 17  366013.0  Heat: Pedal to the Metal    Ahmadneama
#
#                                               comment  rating  text_length  \
# 1                 Should have been an LCG, not a TCG.     1.0           35
# 2   Big surprise news in 2023 of this 2024 Star Wa...     NaN          467
# 4   I was a little disappointed with Heat after my...     7.5          629
# 6    Shrinkwrap  BIN: Not for sale/trade at this time     NaN           48
# 7   It's fine. I would rather play Automobiles or ...     6.0           61
# 10  Light deck building racing game. Basic game is...     8.0          152
# 11  2 plays / 2, 3 players  LIKE: Fast to play, si...     7.0          768
# 13  This is just a fantastic game, and I need a fe...     9.5          153
# 16  I played with Formula D several times, but nev...     8.0          282
# 17  Fun racing game that doesn't punish players fo...     8.5          179
#
#     word_count
# 1            8
# 2           79
# 4          121
# 6            8
# 7           10
# 10          26
# 11         139
# 13          32
# 16          52
# 17          32

# %%
result.to_csv('pre_processed_comment_data_demo.csv', index=False)

# %% [markdown]
# Try to find words unrelated that may be blacklisted from the dataset.

# %% [markdown]
# ### Steps to Clean the Data
# #### Punctuation Removal
# Then try to find relevant key words.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import json
import os
import numpy as np
path_original_data=r'C:\Users\Usuario\Documents\JupyterFolder\unimi_files\IR'
df=pd.read_csv(os.path.join(path_original_data,'pre_processed_comment_data_demo.csv'), low_memory=False)

# %%
import string

def remove_punctuation(text):
    # Create a set of allowed characters (letters and numbers)
    allowed_chars = set(string.ascii_letters + string.digits + ' ')
    
    # Remove punctuation characters not in the allowed set
    processed_text = ''.join(char for char in text if char in allowed_chars)
    
    return processed_text

# Apply the remove_punctuation() function to the 'text' column
df['processed_comment'] = df['comment'].apply(remove_punctuation)

# %% [markdown]
# #### Lowering the Text

# %%
# Lower case all the messages
df['processed_comment'] = df['processed_comment'].str.lower()

# %% [markdown]
# #### Tokenization

# %%
# Defining function for tokenization
import re

def tokenization(text):
    tokens = re.split(' ',text)
    
    return tokens

# Applying function to the column
df['comment_tokenied']= df['processed_comment'].apply(lambda x: tokenization(x))

# %% [markdown]
# #### Stop Word Removal

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
import nltk
#nltk.download('wordnet')

# Stop words present in the library
stopwords = nltk.corpus.stopwords.words('english')
print(stopwords[0:10])

# Defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    
    return output

def remove_short_words(text):
    output= [i for i in text if len(i) > 2]
    
    return output

# Applying the function
df['comment_key_words']= df['comment_tokenied'].apply(lambda x:remove_stopwords(x))
df['comment_key_words']= df['comment_key_words'].apply(lambda x:remove_short_words(x))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %% [markdown]
# #### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Defining the object for stemming
porter_stemmer = PorterStemmer()

# Defining a function for stemming
def stemming(text):
    stem_text = [porter_stemmer.stem(word) for word in text]

    return stem_text

df['comment_stemmed']= df['comment_key_words'].apply(lambda x: stemming(x))

# %% [markdown]
# #### Lemmatization

# %%
import nltk
# nltk.download('wordnet')
# nltk.download('omw-1.4')

from nltk.stem import WordNetLemmatizer

# Defining the object for Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()

# Defining the function for lemmatization
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    
    return lemm_text

df['comment_lemmatized']= df['comment_key_words'].apply(lambda x:lemmatizer(x))

# %% [markdown]
# ### Gensim tutorial

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(400)
import nltk
#nltk.download('wordnet')

stemmer = SnowballStemmer("english")

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

# Tokenize and lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text) :
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 2:
            result.append(lemmatize_stemming(token))
    return result

def preprocess_verbs(text):
    text = gensim.utils.simple_preprocess(text)
    tagged_tokens = nltk.pos_tag(text)
    filtered_tokens = [token for token, pos_tag in tagged_tokens if pos_tag not in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']]
    
    result = []
    for token in filtered_tokens:
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 2:
            result.append(lemmatize_stemming(token))
    return result

df['gensim_comment']= df['comment'].apply(preprocess)
df['gensim_comment_verbs']= df['comment'].apply(preprocess_verbs)

# %% [markdown]
# #### Restructring the dataset
# Rearrage the columns and drop the ones you find not useful.

# %%
# Sort columns
list(df.columns)
# Out:
# ['id',
#  'title',
#  'user',
#  'comment',
#  'rating',
#  'text_length',
#  'word_count',
#  'processed_comment',
#  'comment_tokenied',
#  'comment_key_words',
#  'comment_stemmed',
#  'comment_lemmatized',
#  'gensim_comment',
#  'gensim_comment_verbs']

# %%
df.sample(5)
# Out:
#              id          title         user  \
# 46248  237182.0           Root   bucklen_uk
# 72097  230802.0           Azul       Tariff
# 56329  169786.0         Scythe       athiel
# 24783  162886.0  Spirit Island  Wildman0326
# 38790  174430.0     Gloomhaven      71gamer
#
#                                                  comment  rating  text_length  \
# 46248  I can see why many people love this. I don’t. ...     3.0          213
# 72097          Lovely production and fun little abstract     7.0           41
# 56329  Moves along.  Many rules are a bit tricky.  Bu...     8.8          185
# 24783  The second of three games I will play every ti...     9.9          170
# 38790  Trade local only, this isn't shippable. Also, ...     NaN          157
#
#        word_count                                  processed_comment  \
# 46248          38  i can see why many people love this i dont   t...
# 72097           6          lovely production and fun little abstract
# 56329          34  moves along  many rules are a bit tricky  but ...
# 24783          32  the second of three games i will play every ti...
# 38790          27  trade local only this isnt shippable also plea...
#
#                                         comment_tokenied  \
# 46248  [i, can, see, why, many, people, love, this, i...
# 72097   [lovely, production, and, fun, little, abstract]
# 56329  [moves, along, , many, rules, are, a, bit, tri...
# 24783  [the, second, of, three, games, i, will, play,...
# 38790  [trade, local, only, this, isnt, shippable, al...
#
#                                        comment_key_words  \
# 46248  [see, many, people, love, dont, asymmetric, me...
# 72097        [lovely, production, fun, little, abstract]
# 56329  [moves, along, many, rules, bit, tricky, say, ...
# 24783  [second, three, games, play, every, time, aske...
# 38790  [trade, local, isnt, shippable, also, please, ...
#
#                                          comment_stemmed  \
# 46248  [see, mani, peopl, love, dont, asymmetr, mean,...
# 72097              [love, product, fun, littl, abstract]
# 56329  [move, along, mani, rule, bit, tricki, say, do...
# 24783  [second, three, game, play, everi, time, ask, ...
# 38790  [trade, local, isnt, shippabl, also, pleas, ma...
#
#                                       comment_lemmatized  \
# 46248  [see, many, people, love, dont, asymmetric, me...
# 72097        [lovely, production, fun, little, abstract]
# 56329  [move, along, many, rule, bit, tricky, say, do...
# 24783  [second, three, game, play, every, time, asked...
# 38790  [trade, local, isnt, shippable, also, please, ...
#
#                                           gensim_comment  \
# 46248  [peopl, love, asymmetr, mean, newbi, crush, ex...
# 72097              [love, product, fun, littl, abstract]
# 56329  [move, rule, bite, tricki, bother, littl, time...
# 24783  [second, game, play, time, ask, prefer, play, ...
# 38790  [trade, local, isn, shippabl, sure, trade, req...
#
#                                     gensim_comment_verbs
# 46248  [peopl, asymmetr, mean, newbi, expert, equal, ...
# 72097              [love, product, fun, littl, abstract]
# 56329  [move, rule, bite, tricki, bother, littl, time...
# 24783  [second, game, time, prefer, scenario, adversa...
# 38790  [trade, local, isn, shippabl, sure, trade, req...

# %%
df = df[['gensim_comment', 'gensim_comment_verbs', 'id', 'title', 'user', 'rating', 'comment', 'text_length', 'word_count', 
       'processed_comment', 'comment_key_words', 'comment_tokenied', 'comment_stemmed', 'comment_lemmatized']]

# %%
df = df[df['gensim_comment'].map(lambda d: len(d)) >= 5]
df = df.reset_index(drop=True)

df.sample(5)
# Out:
#                                           gensim_comment  \
# 70198  [play, gencon, home, player, obvious, great, t...
# 66741  [premium, sleev, raptor, print, insert, paint,...
# 32518  [love, stori, build, theme, deck, build, game,...
# 58746  [impress, extrem, product, qualiti, artwork, p...
# 25181  [obvious, game, pleasur, look, play, card, gam...
#
#                                     gensim_comment_verbs        id  \
# 70198  [play, gencon, home, player, obvious, great, t...  345972.0
# 66741  [premium, raptor, print, insert, miniatur, int...  167355.0
# 32518  [stori, build, theme, deck, build, game, artwo...  205637.0
# 58746  [impress, extrem, product, qualiti, artwork, p...  336986.0
# 25181  [obvious, game, pleasur, card, game, piec, stu...  266192.0
#
#                                 title           user  rating  \
# 70198  Cat in the Box: Deluxe Edition  Stealthmutant     7.5
# 66741                         Nemesis        Wardoxx    10.0
# 32518    Arkham Horror: The Card Game        kydaria     9.0
# 58746                      Flamecraft    DopeforHope     8.5
# 25181                        Wingspan     BlueMissed     9.0
#
#                                                  comment  text_length  \
# 70198  After 5 plays at Gencon and home, 2 and 4 play...          226
# 66741  Premium Sleeved E-raptor UV Print Insert Paint...          559
# 32518  Love the story building, theme and deck buildi...          432
# 58746  First impression - seems to be extremely well ...          153
# 25181  Obviously this game is a pleasure to look at a...          292
#
#        word_count                                  processed_comment  \
# 70198          42  after 5 plays at gencon and home 2 and 4 playe...
# 66741         110  premium sleeved eraptor uv print insert painte...
# 32518          78  love the story building theme and deck buildin...
# 58746          26  first impression  seems to be extremely well d...
# 25181          58  obviously this game is a pleasure to look at a...
#
#                                        comment_key_words  \
# 70198  [plays, gencon, home, player, obviously, great...
# 66741  [premium, sleeved, eraptor, print, insert, pai...
# 32518  [love, story, building, theme, deck, building,...
# 58746  [first, impression, seems, extremely, well, do...
# 25181  [obviously, game, pleasure, look, well, play, ...
#
#                                         comment_tokenied  \
# 70198  [after, 5, plays, at, gencon, and, home, 2, an...
# 66741  [premium, sleeved, eraptor, uv, print, insert,...
# 32518  [love, the, story, building, theme, and, deck,...
# 58746  [first, impression, , seems, to, be, extremely...
# 25181  [obviously, this, game, is, a, pleasure, to, l...
#
#                                          comment_stemmed  \
# 70198  [play, gencon, home, player, obvious, great, t...
# 66741  [premium, sleev, eraptor, print, insert, paint...
# 32518  [love, stori, build, theme, deck, build, game,...
# 58746  [first, impress, seem, extrem, well, done, pro...
# 25181  [obvious, game, pleasur, look, well, play, car...
#
#                                       comment_lemmatized
# 70198  [play, gencon, home, player, obviously, great,...
# 66741  [premium, sleeved, eraptor, print, insert, pai...
# 32518  [love, story, building, theme, deck, building,...
# 58746  [first, impression, seems, extremely, well, do...
# 25181  [obviously, game, pleasure, look, well, play, ...

# %%
average_length = df['gensim_comment'].apply(lambda x: len(x)).mean()
print(average_length)
# Out:
# 26.55023453692593

# %%
df.to_csv('post_processed_comment_data_demo.csv', index=False)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import json
import os
import numpy as np
path_original_data=r'C:\Users\Usuario\Documents\JupyterFolder\unimi_files\IR'
df=pd.read_csv(os.path.join(path_original_data,'post_processed_comment_data_demo.csv'), low_memory=False)

# %%
df.sample(10)
# Out:
#                                           gensim_comment  \
# 20721  ['play', 'like', 'despit', 'difficulti', 'rate...
# 6373   ['design', 'gameplay', 'balanc', 'variant', 'g...
# 12491  ['play', 'time', 'love', 'game', 'theme', 'abs...
# 67920  ['enjoy', 'variabl', 'game', 'constant', 'accu...
# 69403  ['giant', 'game', 'consid', 'giant', 'board', ...
# 49656  ['play', 'game', 'unnecessarili', 'complex', '...
# 705    ['eta', 'june', 'dux', 'delay', 'https', 'www'...
# 42672  ['game', 'look', 'board', 'game', 'expans', 'a...
# 26976  ['pretti', 'artwork', 'interest', 'engin', 'bu...
# 13398  ['yes', 'long', 'lot', 'downtim', 'fun', 'abl'...
#
#                                     gensim_comment_verbs        id  \
# 20721  ['despit', 'difficulti', 'rate', 'higher', 'pl...  162886.0
# 6373   ['gameplay', 'variant', 'gameplay', 'deckbuild...  316554.0
# 12491  ['time', 'game', 'theme', 'absolut', 'idea', '...  167791.0
# 67920  ['variabl', 'game', 'constant', 'chip', 'upgra...  227935.0
# 69403  ['giant', 'game', 'giant', 'board', 'long', 't...  115746.0
# 49656  ['play', 'game', 'unnecessarili', 'complex', '...  169786.0
# 705    ['eta', 'june', 'dux', 'https', 'www', 'kickst...  331106.0
# 42672  ['game', 'look', 'board', 'game', 'expans', 'l...  237182.0
# 26976  ['pretti', 'artwork', 'interest', 'engin', 'bu...  266192.0
# 13398  ['yes', 'long', 'lot', 'downtim', 'fun', 'abl'...  167791.0
#
#                                  title           user  rating  \
# 20721                    Spirit Island     phildelvec     8.0
# 6373                    Dune: Imperium       Omnidude     9.3
# 12491                Terraforming Mars   elTigreCHino    10.0
# 67920                 Wonderland's War       Solofunk     8.0
# 69403  War of the Ring: Second Edition          Raeez     9.2
# 49656                           Scythe         Albarc     7.0
# 705             The Witcher: Old World  VaeVictis1918     NaN
# 42672                             Root          nicku     9.0
# 26976                         Wingspan        Illusia     8.0
# 13398                Terraforming Mars      Ibaimendi     9.0
#
#                                                  comment  text_length  \
# 20721  Played this once and really liked it despite i...          103
# 6373   It's a really well Designed Gameplay and well-...          581
# 12491  I don't own it. I have played it three times. ...          354
# 67920  Really enjoyed the variability in this game. Y...          719
# 69403  Giant game, considering a giant board, long se...          215
# 49656  After one play, I found the game unnecessarily...          123
# 705    Eta June 2022. Dux. Delayed. https://www.kicks...           87
# 42672  This game is almost everything I look for in a...          101
# 26976  Pretty artwork. Interesting engine building ga...          222
# 13398  Yes, it's long and has a lot of downtime, but ...          419
#
#        word_count                                  processed_comment  \
# 20721          17  played this once and really liked it despite i...
# 6373           99  its a really well designed gameplay and wellba...
# 12491          69  i dont own it i have played it three times i l...
# 67920         126  really enjoyed the variability in this game yo...
# 69403          37  giant game considering a giant board long set ...
# 49656          22  after one play i found the game unnecessarily ...
# 705             6  eta june 2022 dux delayed httpswwwkickstarterc...
# 42672          21  this game is almost everything i look for in a...
# 26976          42  pretty artwork interesting engine building gam...
# 13398          79  yes its long and has a lot of downtime but its...
#
#                                        comment_key_words  \
# 20721  ['played', 'really', 'liked', 'despite', 'diff...
# 6373   ['really', 'well', 'designed', 'gameplay', 'we...
# 12491  ['dont', 'played', 'three', 'times', 'love', '...
# 67920  ['really', 'enjoyed', 'variability', 'game', '...
# 69403  ['giant', 'game', 'considering', 'giant', 'boa...
# 49656  ['one', 'play', 'found', 'game', 'unnecessaril...
# 705    ['eta', 'june', '2022', 'dux', 'delayed', 'htt...
# 42672  ['game', 'almost', 'everything', 'look', 'boar...
# 26976  ['pretty', 'artwork', 'interesting', 'engine',...
# 13398  ['yes', 'long', 'lot', 'downtime', 'fun', 'abl...
#
#                                         comment_tokenied  \
# 20721  ['played', 'this', 'once', 'and', 'really', 'l...
# 6373   ['its', 'a', 'really', 'well', 'designed', 'ga...
# 12491  ['i', 'dont', 'own', 'it', 'i', 'have', 'playe...
# 67920  ['really', 'enjoyed', 'the', 'variability', 'i...
# 69403  ['giant', 'game', 'considering', 'a', 'giant',...
# 49656  ['after', 'one', 'play', 'i', 'found', 'the', ...
# 705    ['eta', 'june', '2022', 'dux', 'delayed', 'htt...
# 42672  ['this', 'game', 'is', 'almost', 'everything',...
# 26976  ['pretty', 'artwork', 'interesting', 'engine',...
# 13398  ['yes', 'its', 'long', 'and', 'has', 'a', 'lot...
#
#                                          comment_stemmed  \
# 20721  ['play', 'realli', 'like', 'despit', 'difficul...
# 6373   ['realli', 'well', 'design', 'gameplay', 'well...
# 12491  ['dont', 'play', 'three', 'time', 'love', 'gam...
# 67920  ['realli', 'enjoy', 'variabl', 'game', 'consta...
# 69403  ['giant', 'game', 'consid', 'giant', 'board', ...
# 49656  ['one', 'play', 'found', 'game', 'unnecessaril...
# 705    ['eta', 'june', '2022', 'dux', 'delay', 'https...
# 42672  ['game', 'almost', 'everyth', 'look', 'board',...
# 26976  ['pretti', 'artwork', 'interest', 'engin', 'bu...
# 13398  ['ye', 'long', 'lot', 'downtim', 'fun', 'abl',...
#
#                                       comment_lemmatized
# 20721  ['played', 'really', 'liked', 'despite', 'diff...
# 6373   ['really', 'well', 'designed', 'gameplay', 'we...
# 12491  ['dont', 'played', 'three', 'time', 'love', 'g...
# 67920  ['really', 'enjoyed', 'variability', 'game', '...
# 69403  ['giant', 'game', 'considering', 'giant', 'boa...
# 49656  ['one', 'play', 'found', 'game', 'unnecessaril...
# 705    ['eta', 'june', '2022', 'dux', 'delayed', 'htt...
# 42672  ['game', 'almost', 'everything', 'look', 'boar...
# 26976  ['pretty', 'artwork', 'interesting', 'engine',...
# 13398  ['yes', 'long', 'lot', 'downtime', 'fun', 'abl...

# %%
# Let's check the posts that contains found words that could help us filter

print(len(df[df.comment.str.contains('luck')]))
print(len(df[df.comment.str.contains('random')]))
print(len(df[df.comment.str.contains('boring')]))
print(len(df[df.comment.str.contains('complex')]))
print(len(df[df.comment.str.contains('complicated')]))
print(len(df[df.comment.str.contains('bookkeeping')]))

df[df.comment.str.contains('boring')].sample(5)
# Out:
# 3097
# 2755
# 1185
# 3057
# 868
# 130
#                                           gensim_comment  \
# 28591  ['nice', 'pleasant', 'game', 'fun', 'manag', '...
# 66141  ['super', 'themat', 'play', 'take', 'care', 'b...
# 30472  ['think', 'player', 'run', 'bite', 'long', 'wa...
# 55787  ['decent', 'econom', 'game', 'nice', 'mechan',...
# 54925  ['like', 'row', 'action', 'player', 'board', '...
#
#                                     gensim_comment_verbs        id     title  \
# 28591  ['nice', 'pleasant', 'game', 'fun', 'bird', 't...  266192.0  Wingspan
# 66141  ['super', 'themat', 'care', 'bore', 'stuff', '...  167355.0   Nemesis
# 30472  ['think', 'player', 'bite', 'long', 'player', ...  266192.0  Wingspan
# 55787  ['decent', 'econom', 'game', 'nice', 'mechan',...  169786.0    Scythe
# 54925  ['like', 'row', 'action', 'player', 'board', '...  169786.0    Scythe
#
#               user  rating                                            comment  \
# 28591  Nyanapulsar     9.0  Very nice and pleasant game. It's very fun to ...
# 66141      Peneda1     8.3  Super thematic. I played with someone who took...
# 30472    wafflebun     3.0  I think at 5 players it ran a bit long and the...
# 55787    Valcurdra     4.0  Decent economic game with some nice mechanisms...
# 54925    sighlance     1.0  I don't like that the "bottom-row actions" on ...
#
#        text_length  word_count  \
# 28591          653         118
# 66141          506          94
# 30472          368          67
# 55787          686         118
# 54925         1746         279
#
#                                        processed_comment  \
# 28591  very nice and pleasant game its very fun to ma...
# 66141  super thematic i played with someone who took ...
# 30472  i think at 5 players it ran a bit long and the...
# 55787  decent economic game with some nice mechanisms...
# 54925  i dont like that the bottomrow actions on the ...
#
#                                        comment_key_words  \
# 28591  ['nice', 'pleasant', 'game', 'fun', 'manage', ...
# 66141  ['super', 'thematic', 'played', 'someone', 'to...
# 30472  ['think', 'players', 'ran', 'bit', 'long', 'wa...
# 55787  ['decent', 'economic', 'game', 'nice', 'mechan...
# 54925  ['dont', 'like', 'bottomrow', 'actions', 'play...
#
#                                         comment_tokenied  \
# 28591  ['very', 'nice', 'and', 'pleasant', 'game', 'i...
# 66141  ['super', 'thematic', 'i', 'played', 'with', '...
# 30472  ['i', 'think', 'at', '5', 'players', 'it', 'ra...
# 55787  ['decent', 'economic', 'game', 'with', 'some',...
# 54925  ['i', 'dont', 'like', 'that', 'the', 'bottomro...
#
#                                          comment_stemmed  \
# 28591  ['nice', 'pleasant', 'game', 'fun', 'manag', '...
# 66141  ['super', 'themat', 'play', 'someon', 'took', ...
# 30472  ['think', 'player', 'ran', 'bit', 'long', 'was...
# 55787  ['decent', 'econom', 'game', 'nice', 'mechan',...
# 54925  ['dont', 'like', 'bottomrow', 'action', 'playe...
#
#                                       comment_lemmatized
# 28591  ['nice', 'pleasant', 'game', 'fun', 'manage', ...
# 66141  ['super', 'thematic', 'played', 'someone', 'to...
# 30472  ['think', 'player', 'ran', 'bit', 'long', 'was...
# 55787  ['decent', 'economic', 'game', 'nice', 'mechan...
# 54925  ['dont', 'like', 'bottomrow', 'action', 'playe...

# %%
print(len(df[df.comment.str.contains('edition')]))
print(len(df[df.comment.str.contains('version')]))
print(len(df[df.comment.str.contains('expansion')]))
# Out:
# 1177
# 2136
# 5469
